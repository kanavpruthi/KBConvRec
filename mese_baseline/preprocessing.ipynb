# %%
import torch

# %%
movie_dict = torch.load('data/processed/redial_full_movie_db_placeholder')

# %%
movie_dict
# Out:
# {4495: 'final fantasy: the spirits within [SEP] Ming-Na Wen, Alec Baldwin, Ving Rhames, Steve Buscemi [SEP] Hironobu Sakaguchi, Motonori Sakakibara(co-director) [SEP] Animation, Action, Adventure, Fantasy, Romance, Sci-Fi [SEP] A scientist makes a last stand on Earth with the help of a ragtag team of soldiers against an invasion of alien phantoms.',
#  8315: 'mary and max [SEP] Christopher Massey, Oliver Marks, Daisy Kocher, Daniel Marks [SEP] Adam Elliot [SEP] Animation, Comedy, Drama [SEP] A tale of friendship between two unlikely pen pals: Mary, a lonely, eight-year-old girl living in the suburbs of Melbourne, and Max, a forty-four-year old, severely obese man living in New York.',
#  513: 'the boss baby [SEP] Alec Baldwin, Steve Buscemi, Jimmy Kimmel, Lisa Kudrow [SEP] Tom McGrath [SEP] Animation, Adventure, Comedy, Family, Fantasy [SEP] A suit-wearing, briefcase-carrying baby pairs up with his 7-year old brother to stop the dastardly plot of the CEO of Puppy Co.',
# ...
